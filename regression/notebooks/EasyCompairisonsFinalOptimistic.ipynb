# %%
import numpy as np
import pickle 
import sys, os
sys.path.append("..")
from logger import Logger
import matplotlib.pyplot as plt

# %%
def get_logger(pth):
    with open(pth, 'rb') as f:
        logger = pickle.load(f)
    logger.train_loss = np.asarray(logger.train_loss)
    logger.train_conf = np.asarray(logger.train_conf)

    logger.valid_loss = np.asarray(logger.valid_loss)
    logger.valid_conf = np.asarray(logger.valid_conf)

    logger.test_loss = np.asarray(logger.test_loss)
    logger.test_conf = np.asarray(logger.test_conf)

    logger.elapsed_time = np.asarray(logger.elapsed_time)
    
    return logger

# %%
amnts = ['100', '1000', '10000']# '10000',]# '100000']
cva_pref = '../cva_sine_result_files/finalreset_10000_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

# %%
# plot the performance of everything
alpha = 0.2
for i, logger in loggers.items():
    for j, l in logger.items():
        x = [j for j in range(len(l.test_loss))]
        plt.plot(x, l.test_loss, label=i+j)
        plt.fill_between(x, l.test_loss+l.test_conf, l.test_loss-l.test_conf, alpha=alpha)
plt.legend()
fig = plt.gcf()
fig.set_size_inches(15,6)
# plt.ylim(0,.5)
plt.show()

# %%
# performance vs time 
# plot each method on its own plot

plt.subplot(3, 1, 1)
s = 4
for i, l in loggers['cva'].items():
    x = l.elapsed_time[::s]
    plt.plot(x, l.test_loss[::s], label='cva'+i)
    plt.fill_between(x, l.test_loss[::s]+l.test_conf[::s], l.test_loss[::s]-l.test_conf[::s], alpha=alpha)
plt.legend()
plt.ylim(0,2)
    
plt.subplot(3, 1, 2)
for i, l in loggers['cavia'].items():
    x = l.elapsed_time
    plt.plot(x, l.test_loss, label='cavia'+i)
    plt.fill_between(x, l.test_loss+l.test_conf, l.test_loss-l.test_conf, alpha=alpha)
plt.legend()
plt.ylim(0,1)
    
plt.subplot(3, 1, 3)
for i, l in loggers['maml'].items():
    x = l.elapsed_time
    plt.plot(x, l.test_loss, label='maml'+i)
    plt.fill_between(x, l.test_loss+l.test_conf, l.test_loss-l.test_conf, alpha=alpha)
plt.legend()

fig = plt.gcf()
fig.set_size_inches(15,10)
plt.ylim(0,1)
plt.show()

# %%
cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('Reset_Emb=10000, Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# plot of performance vs time for the 1000000 case
# plot the performance of everything
alpha = 0.2
numpoints = '100'
for lbl in ['cva', 'cavia', 'maml']:
    x, y, s = loggers[lbl][numpoints].elapsed_time, loggers[lbl][numpoints].test_loss, loggers[lbl][numpoints].test_conf
    plt.plot(x, y, label=lbl)
    plt.fill_between(x, y+s, y-s, alpha=alpha)

plt.legend()
plt.title('MSE vs Elapsed Time')
plt.ylabel('MSE')
plt.xlabel('time (s)')
fig = plt.gcf()
fig.set_size_inches(8,5)
plt.ylim(0,2)
plt.show()

# %%
# plot of performance vs time for the 1000000 case
# plot the performance of everything
alpha = 0.2
numpoints = '10000'
for lbl in ['cva', 'cavia', 'maml']:
    x, y, s = loggers[lbl][numpoints].training_time, loggers[lbl][numpoints].test_loss, loggers[lbl][numpoints].test_conf
    plt.plot(x, y, label=lbl)
    plt.fill_between(x, y+s, y-s, alpha=alpha)

plt.legend()
plt.title('MSE vs Elapsed Time')
plt.ylabel('MSE')
plt.xlabel('time (s)')
fig = plt.gcf()
fig.set_size_inches(8,5)
plt.ylim(0,2)
plt.xlim(-10 ,5000)
plt.show()

# %%
# new cva data wrt time vs maml and cva with 10 inner updates. 
amnts = ['100', '1000', '10000']# '10000',]# '100000']
cva_pref = '../cva_sine_result_files/do0.5_lr0.0005_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

alpha = 0.2
numpoints = '10000'
for lbl in ['cva', 'cavia', 'maml']:
    x, y, s = loggers[lbl][numpoints].training_time, loggers[lbl][numpoints].test_loss, loggers[lbl][numpoints].test_conf
    plt.plot(x, y, label=lbl)
    plt.fill_between(x, y+s, y-s, alpha=alpha)

plt.legend()
plt.title('MSE vs Elapsed Time')
plt.ylabel('MSE')
plt.xlabel('time (s)')
fig = plt.gcf()
fig.set_size_inches(8,5)
plt.ylim(0,2)
plt.xlim(-10 ,5000)
plt.show()

# %% [markdown]
# From here below are just recreations of the bar chart for different experiments

# %%
# Low learning rate 
amnts = ['10', '100', '1000']  #, '10000', '100000']
cva_pref = '../cva_sine_result_files/lowlr__'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('Low Learning rate: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Long evaluation
amnts = ['10', '100', '1000', '10000'] #, '100000']
cva_pref = '../cva_sine_result_files/longeval__'
cva_suff = '_50_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('longer training: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Long evaluation
amnts = ['10', '100', '1000']#, '10000'] #, '100000']
cva_pref = '../cva_sine_result_files/finalreset_1_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('EmbResetFreq=1: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Long evaluation
amnts = ['100', '1000', '10000'] #, '100000']
cva_pref = '../cva_sine_result_files/finalreset_100_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('EmbResetFreq=100: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Long evaluation
amnts = ['100', '1000', '10000'] #, '100000']
cva_pref = '../cva_sine_result_files/finalreset_1000_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('EmbResetFreq=1000: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Long evaluation
amnts = ['100', '1000', '10000'] #, '100000']
cva_pref = '../cva_sine_result_files/finalreset_10000_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('EmbResetFreq=10000: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, 1)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# embedding learning rate smaller
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/difflrs_irsmal_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
# print(len(loggers['cva'][amnt].test_loss))
cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('embLR=0.0001, LR=0.001: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()
# Out:
# 100

# %%
# embedding learning rate smaller
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/difflrs_irbig_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('embLR=0.001, LR=0.0001: Performance Comparison vs Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# embedding learning rate is small, ran for a long time with a lower learning rate, reset after num func iterations
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/longsmaller_elrsmal_rfreqEqNumFns_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('embLR=0.00001, LR=0.0001, reset_emb=Amount of Training Data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# embedding learning rate is small, shared normal, reset every num funcs
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/elrsmal_rfreqEqNumFns_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('embLR=0.0001, LR=0.001, reset_emb=amount of training data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# Normal learning rate, just reset embeddings every num funcs iterations
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/normlr_rfreqEqNumFns_'
cva_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, maml_mins, maml_stds = [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, cva_mins, width, label='cva', yerr=cva_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.001, reset_emb=amount of training data')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# using dropout regularization (these are with p=0)
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/do0_lr0.001_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0_lr0.001_'
bignet_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {},
    'bignet': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, bignet_mins, bignet_stds, maml_mins, maml_stds = [], [], [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['bignet'][amnt].test_loss)
    bignet_mins.append(loggers['bignet'][amnt].test_loss[idx])
    bignet_stds.append(loggers['bignet'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.15

fig, ax = plt.subplots()
rects1 = ax.bar(x-1.5*width, cva_mins, width, label='cva', yerr=cva_stds)
rects15 = ax.bar(x-.5*width, bignet_mins, width, label='bignet', yerr=bignet_stds)
rects2 = ax.bar(x+.5*width, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+1.5*width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.001, p=0')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# using dropout regularization (these are with p=0) lr=0.005
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/do0_lr0.0005_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0_lr0.0005_'
bignet_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {},
    'bignet': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, bignet_mins, bignet_stds, maml_mins, maml_stds = [], [], [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['bignet'][amnt].test_loss)
    bignet_mins.append(loggers['bignet'][amnt].test_loss[idx])
    bignet_stds.append(loggers['bignet'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.15

fig, ax = plt.subplots()
rects1 = ax.bar(x-1.5*width, cva_mins, width, label='cva', yerr=cva_stds)
rects15 = ax.bar(x-.5*width, bignet_mins, width, label='bignet', yerr=bignet_stds)
rects2 = ax.bar(x+.5*width, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+1.5*width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.0005, p=0')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# using dropout regularization (these are with p=0.25) lr=0.001
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/do0.25_lr0.001_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0.25_lr0.001_'
bignet_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
#     'cva': {},
    'cavia': {},
    'maml': {},
    'bignet': {}
}
for amnt in amnts:
#     loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, bignet_mins, bignet_stds, maml_mins, maml_stds = [], [], [], [], [], [], [], []
for amnt in amnts:
#     idx = np.argmin(loggers['cva'][amnt].test_loss)
#     cva_mins.append(loggers['cva'][amnt].test_loss[idx])
#     cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['bignet'][amnt].test_loss)
    bignet_mins.append(loggers['bignet'][amnt].test_loss[idx])
    bignet_stds.append(loggers['bignet'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.15

fig, ax = plt.subplots()
# rects1 = ax.bar(x-1.5*width, cva_mins, width, label='cva', yerr=cva_stds)
rects15 = ax.bar(x-width, bignet_mins, width, label='bignet', yerr=bignet_stds)
rects2 = ax.bar(x, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.001, p=0.25')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# using dropout regularization (these are with p=0.5) lr =0.001
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/do0.5_lr0.001_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0.5_lr0.001_'
bignet_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {},
    'bignet': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, bignet_mins, bignet_stds, maml_mins, maml_stds = [], [], [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['bignet'][amnt].test_loss)
    bignet_mins.append(loggers['bignet'][amnt].test_loss[idx])
    bignet_stds.append(loggers['bignet'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.15

fig, ax = plt.subplots()
rects1 = ax.bar(x-1.5*width, cva_mins, width, label='cva', yerr=cva_stds)
rects15 = ax.bar(x-.5*width, bignet_mins, width, label='bignet', yerr=bignet_stds)
rects2 = ax.bar(x+.5*width, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+1.5*width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.001, p=0.5')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# using dropout regularization (these are with p=0.5) lr =0.0005
amnts = ['10', '100', '1000', '10000', '100000']
cva_pref = '../cva_sine_result_files/do0.5_lr0.0005_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0.5_lr0.0005_'
bignet_suff = '_40_0_1.pkl'
cavia_pref = '../sine_result_files/final'
cavia_suff = '__10_25.pkl'
maml_pref = '../maml_sine_result_files/final'
maml_suff = '__10_25.pkl'
loggers = {
    'cva': {},
    'cavia': {},
    'maml': {},
    'bignet': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['cavia'][amnt] = get_logger(cavia_pref + amnt + cavia_suff)
    loggers['maml'][amnt] = get_logger(maml_pref + amnt + maml_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

cva_mins, cva_stds, cavia_mins, cavia_stds, bignet_mins, bignet_stds, maml_mins, maml_stds = [], [], [], [], [], [], [], []
for amnt in amnts:
    idx = np.argmin(loggers['cva'][amnt].test_loss)
    cva_mins.append(loggers['cva'][amnt].test_loss[idx])
    cva_stds.append(loggers['cva'][amnt].test_conf[idx])
    idx = np.argmin(loggers['bignet'][amnt].test_loss)
    bignet_mins.append(loggers['bignet'][amnt].test_loss[idx])
    bignet_stds.append(loggers['bignet'][amnt].test_conf[idx])
    idx = np.argmin(loggers['cavia'][amnt].test_loss)
    cavia_mins.append(loggers['cavia'][amnt].test_loss[idx])
    cavia_stds.append(loggers['cavia'][amnt].test_conf[idx])
    idx = np.argmin(loggers['maml'][amnt].test_loss)
    maml_mins.append(loggers['maml'][amnt].test_loss[idx])
    maml_stds.append(loggers['maml'][amnt].test_conf[idx])

xlabels = amnts
x = np.arange(len(xlabels))
width = 0.15

fig, ax = plt.subplots()
rects1 = ax.bar(x-1.5*width, cva_mins, width, label='cva', yerr=cva_stds)
rects15 = ax.bar(x-.5*width, bignet_mins, width, label='bignet', yerr=bignet_stds)
rects2 = ax.bar(x+.5*width, cavia_mins, width, label='cavia', yerr=cavia_stds)
rects3 = ax.bar(x+1.5*width, maml_mins, width, label='maml', yerr=maml_stds)
ax.set_ylabel('MSE')
ax.set_xlabel('Amount of Training Data')
ax.set_title('lr=0.0005, p=0.5')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend() 
# plt.ylim(0, .2)

fig.tight_layout()

fig = plt.gcf()
fig.set_size_inches(8,5)

plt.show()

# %%
# are we just not training long enough when using dropout?
# using dropout regularization (these are with p=0.5) lr =0.0005
amnts = ['10', '1000', '100000']
cva_pref = '../cva_sine_result_files/do0.5_lr0.0005_'
cva_suff = '_40_0_1.pkl'
bignet_pref = '../cva_sine_result_files/bignet_do0.5_lr0.0005_'
bignet_suff = '_40_0_1.pkl'

loggers = {
    'cva': {},
    'bignet': {}
}
for amnt in amnts:
    loggers['cva'][amnt] = get_logger(cva_pref + amnt + cva_suff)
    loggers['bignet'][amnt] = get_logger(bignet_pref + amnt + bignet_suff)

for i, logger in loggers.items():
    for j, l in logger.items():
        x = [j for j in range(len(l.test_loss))]
        plt.plot(x, l.test_loss, label=i+j)
        plt.fill_between(x, l.test_loss+l.test_conf, l.test_loss-l.test_conf, alpha=0.2)
plt.legend()
fig = plt.gcf()
fig.set_size_inches(15,6)
plt.ylim(0,1)
plt.show()
